# %%
import pandas as pd
import numpy as np
import sys
import warnings
warnings.filterwarnings('ignore')
from copy import deepcopy,copy
from datetime import datetime
import pickle
import os
import scipy
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures

# Import Machine Scientist
from importlib.machinery import SourceFileLoader
# Get the absolute path of the script's directory
script_dir = os.getcwd()
# Define the relative path to the module
relative_module_path = "rguimera-machine-scientist-constrained/machinescientist_ode.py"
path = os.path.join(script_dir, relative_module_path)
ms_ode = SourceFileLoader("ms_ode", path).load_module()


folder_name = 'Train_test_data_lin_term_com2025_03_11-11_21_44'
"""
with open(f'./{folder_name}/x.pkl', 'rb') as file:
    # A new file will be created
    x = pickle.load(file)
    
with open(f'./{folder_name}/y.pkl', 'rb') as file:
    # A new file will be created
    y = pickle.load(file)
"""
with open(f'./{folder_name}/x_test.pkl', 'rb') as file:
    # A new file will be created
    x=pickle.load(file)
    
with open(f'./{folder_name}/y_test.pkl', 'rb') as file:
    # A new file will be created
    y=pickle.load(file)

def RK_BMS(model,y0,h,steps,col):
    res=[y0]
    for i in range(steps-1):
        k1 = h*model.predict({col:pd.DataFrame(data={'B':[res[-1]]})})[col].to_numpy()[0]
        k2 = h*model.predict({col:pd.DataFrame(data={'B':[res[-1]+k1/2.]})})[col].to_numpy()[0]
        k3 = h*model.predict({col:pd.DataFrame(data={'B':[res[-1]+k2/2.]})})[col].to_numpy()[0]
        k4 = h*model.predict({col:pd.DataFrame(data={'B':[res[-1]+k3]})})[col].to_numpy()[0]

        # Calculate new x and y
        res.append(res[-1] + 1./6*(k1+2*k2+2*k3+k4))
        """x = x + dx
        f=model.predict({col:pd.DataFrame(data={'B':[res[-1]]})})[col].to_numpy()[0]
        res.append(res[-1]+h*f)"""
    return res



# Uncomment to fit logistic growth

string ='((_a1_ * (B + _a0_)) + ((pow2((B + _a0_)) * _a2_)))' #Logistic
bms_fulldata_new = ms_ode.from_string_model(x,y,string,1,8,['B'],silence=True)
print(bms_fulldata_new.E)
# Out:
# _a2_
# Fit from fit 0.058196399342557964 -1.3183898417423734e-14
# Fit from par 0.05819639934255791 -1.3016893118944495e-11
# Fit from fit 0.4205057364792883 7.932499979101948e-08
# Fit from par 0.42050573647929307 -5.6377981172417435e-09
# Fit from fit 0.556198850434043 -1.1657341758564144e-14
# Fit from par 0.5561988504340577 -2.1090857948991015e-09
# Fit from fit 0.19955669336637252 -8.424925274086448e-08
# Fit from par 0.19955669336637338 -7.90199788935908e-09
# Fit from fit 0.11032458702572875 -6.994405055138486e-15
# Fit from par 0.11032458702573165 -8.846140098217603e-09
# Fit from fit 0.23311716832738727 -3.9234402066101737e-07
# Fit from par 0.23311716832753845 1.5741913715339173e-06
# Fit from fit 0.2955399601872859 -2.2327197535254584e-08
# Fit from par 0.2955399601872858 -6.622224102414975e-09
# Fit from fit 0.4357122037987616 1.2753062184067687e-07
# Fit from par 0.4357122037987611 1.986755204796964e-11
# Fit from fit 0.11877141614963935 -1.3304248747125769e-07
# Fit from par 0.11877141614963854 -1.882027866884073e-11
# Fit from fit 0.49744737795519195 -4.851674617611934e-14
# Fit from par 0.4974473779551969 3.0072611068021615e-12
# Fit from fit 0.0792194915999603 0.00047568970923081433
# Fit from par 7.356883487952261 -20.506700192965422
# Fit from fit 0.21594676896659876 0.016406379265284876
# Fit from par 18.218056901312178 -32.01407338153001
# Fit from fit 0.24160495192786327 0.015675301758982352
# Fit from par 1.7645932841654314e+22 -195715573875.88452
# Fit from fit 0.28754840635958534 -0.8333508358843428
# Fit from par 4.444094270910165e+20 -31059517609.445587
# Fit from fit 0.18939732773595058 0.10100415380965516
# Fit from par 4.353403945724165e+16 -307409712.5971551
# Fit from fit 0.21795808058563773 0.3002712596877326
# Fit from par 9.226975026924855 -20.273453501467234
# Fit from fit 0.17781721958537416 0.06723075792704253
# Fit from par 7.660950286841457 -20.241789843709494
# Fit from fit 0.5881190872111496 0.28192106497498026
# Fit from par 15.63576192504086 -27.62735729073751
# Fit from fit 0.15318952583368836 0.14908488744970355
# Fit from par 3.7417056771210674e+20 28499542392.204422
# Fit from fit 0.19749818168342792 0.187904872755508
# Fit from par 12.380054993923984 -24.822585996092496
# Fit from fit 0.1895134859646667 0.07434891207445454
# Fit from par 8.137574414492663 -20.818905378862098
# Fit from fit 0.18197556751027955 0.08210141831490228
# Fit from par 154424559.67099017 -18328.303588579514
# Fit from fit 0.29679991263438654 0.1906522916134712
# Fit from par 175360941.99999887 -19534.314196735853
# Fit from fit 0.4385011547684072 0.16563543419738877
# Fit from par 432387025.724948 -30659.662934865926
# Fit from fit 0.16132200819546055 0.1522584831676009
# Fit from par 3.9427754802233045e+21 92513284390.90697
# Fit from fit 0.25422910076063826 0.17366728018243274
# Fit from par 14.02562049626528 -26.69930749447586
# Fit from fit 0.14643289014431135 0.12908218750958125
# Fit from par 7.664138594549868 -19.611020419758184
# Fit from fit 0.12394016758678267 0.12978208013098194
# Fit from par 54571449.3048821 -10903.774856553468
# Fit from fit 0.17612207269684296 0.13400418262410893
# Fit from par 3900347891.097776 91994.18959344803
# Fit from fit 0.7108100582353019 0.5581768195597255
# Fit from par 18.80143493866109 -28.228420548491172
# Fit from fit 0.03427101278817757 -0.049483819397754494
# Fit from par 4.871796634733617 -15.41651962441945
# Fit from fit 0.9042978684928488 0.6829492653859127
# Fit from par 32958554002.864525 -267509.34962575225
# Fit from fit 0.29412952794446046 0.1764001652324056
# Fit from par 138134282.42267507 17294.3732236762
# Fit from fit 0.5989586653526964 0.5371506660485346
# Fit from par 719974853.6585257 -39562.086678676504
# ((_a1_ * B) + B)
# ((_a1_ * (B + B)) + B)
# Fit from fit 0.08036800202701934 0.032680109735327256
# Fit from par 0.08036800202684222 0.032679876657126156
# Fit from fit 0.608898919496675 0.18911194515726748
# Fit from par 0.6088989194914606 0.18911108870904414
# Fit from fit 0.7870341339143395 0.20587563341576703
# Fit from par 0.7870341337935843 0.20590566350933975
# Fit from fit 0.41971841335877397 0.259164580317227
# Fit from par 0.41971841337708693 0.25916759746847085
# Fit from fit 0.22552265886762043 0.1431602856094608
# Fit from par 0.22552265886069064 0.14317645495309167
# Fit from fit 0.707426717097465 0.6767602382185308
# Fit from par 0.7074267173740643 0.6767188569529025
# Fit from fit 0.4398383579326351 0.15952942180602447
# Fit from fit 0.7108100582354041 0.5581767930945525
# Fit from par 0.7108100582687205 0.5582289836886587
# Fit from fit 0.034271012788177596 -0.04948381814009223
# Fit from par 0.034271012788156946 -0.0494843909499664
# Fit from fit 0.9042978684932307 0.6829491485958814
# Fit from par 0.9042978686417099 0.6830217708563173
# Fit from fit 0.2941295279444676 0.17640016567279362
# Fit from par 0.2941295279591744 0.17638393822819837
# Fit from fit 0.5989586653526981 0.5371506566338884
# Fit from par 0.5989586653838397 0.5371822725302962
# ((_a1_ * (B + B)) + B)
# ((_a1_ * (B + B)) + B)
# ((_a1_ * (B + B)) + B)
# ((_a1_ * (B + _a0_)) + B)
# Fit from fit 0.01979656525426064 2.1823948481713984e-09
# Fit from par 0.019796565256452785 6.740013547279489e-10
# Fit from fit 0.10554101353834872 -3.061269851500903e-08
# Fit from par 0.10554101351141622 8.192860208033892e-07
# Fit from fit 0.1596200293408492 -2.8862252413330847e-06
# Fit from par 0.15962002933349775 2.5001576045569074e-06
# Fit from fit 0.07439423365430216 2.77484740740519e-09
# Fit from par 0.07439423365415644 2.0886164742162094e-08
# Fit from fit 0.00976949928739647 1.1946106909244136e-08
# Fit from par 0.009769499287384341 -7.070557750399331e-09
# Fit from fit 0.23235818289093207 3.6781265245200423e-06
# Fit from par 0.23235818289714982 -1.087204870464653e-06
# Fit from fit 0.06600836787721663 -2.0081709878327914e-08
# Fit from par 0.0660083678891214 -8.956057628850544e-08
# Fit from fit 0.04163578133510991 -3.384963695451937e-08
# Fit from par 0.04163578133450877 -3.59411049533076e-09
# Fit from fit 0.01913029376190901 1.0871540473411656e-09
# Fit from par 0.01913029376705207 4.9221744319316585e-09
# Fit from fit 0.06296056589028803 -6.517688944107647e-09
# Fit from par 0.06296056588703183 2.4350411576001818e-08
# Fit from fit 0.05419385226287183 1.8803765072794576e-09
# Fit from par 0.0541938522574174 -1.980134223256158e-09
# Fit from fit 0.12152616055931091 -2.8580093847097032e-08
# Fit from par 0.12152616056577074 2.8659048784129837e-07
# Fit from fit 0.041555589137943015 1.8391404565942793e-08
# Fit from par 0.041555589128839575 -6.26311636164889e-08
# Fit from fit 0.1368636406091099 -2.2061003032702864e-07
# Fit from par 0.13686364058041325 3.277100406595679e-07
# Fit from fit 0.036818313807177816 3.163481557266756e-08
# Fit from par 0.03681831380732545 8.5073752764675e-09
# Fit from fit 0.027891599247912093 2.0785945187284938e-08
# Fit from par 0.027891599245102414 2.053415477931697e-08
# Fit from fit 0.00964454398567828 -4.737786080122319e-09
# Fit from par 0.009644543985515112 7.564554455052885e-09
# Fit from fit 0.045980960131351445 -6.0889258635121735e-09
# Fit from par 0.045980960113859666 1.0207009265572609e-08
# Fit from fit 0.07059637516390788 2.3504632323811947e-08
# Fit from par 0.07059637517412883 -1.1217618084424785e-08
# Fit from fit 0.12455673814765494 -4.968690484052907e-08
# Fit from par 0.12455673810579612 -1.0162843594452298e-07
# Fit from fit 0.013322209866653093 1.4304975787249319e-08
# Fit from par 0.01332220986660863 -1.572565591634323e-08
# Fit from fit 0.012530527561580473 -4.071966319685316e-09
# Fit from fit 0.06782771833568048 1.053233657372088e-07
# Fit from par 0.06782771828566365 5.686727300169281e-08
# Fit from fit 0.0287780053468253 1.5065435562955365e-07
# ...
# Fit from fit nan nan
# Fit from par 0.05442881692265712 0.07270625976303588
# R.S.18 D-Mannose_18
# Get SSE, fit 2 error(x0) No active exception to reraise
# [0.132532, -0.7645112358059519, -0.687596501181607, -1.3880004093330303]
# [0.132532, 0.11055808524905297, -0.9667349468619245, 1.0]
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# No offset fit successful
# results ([0.132532, -0.7645112358059519, -0.687596501181607, -1.3880004093330303], [[0.132532, -0.7645112358059519, -0.687596501181607, -1.3880004093330303], [0.132532, -0.7645112358059519, -0.687596501181607, -1.3880004093330303]])
# curvefit (array([-0.76451124, -0.6875965 , -1.38800041]), array([[inf, inf, inf],
#        [inf, inf, inf],
#        [inf, inf, inf]]))
# curvefit deriv (array([-0.76451124, -0.6875965 , -1.38800041]), array([[ 1.09635222e-03, -9.36325335e-05,  2.26741925e-03],
#        [-9.36325335e-05,  2.99693485e-05, -2.48504095e-04],
#        [ 2.26741925e-03, -2.48504095e-04,  4.84960332e-03]]))
# Inf in cov array. Raising error
# R.S.18 D-Mannose_18
# Get SSE, fit 2 error(no x0) No active exception to reraise
# Par values [0.11055808524905297, -0.9667349468619245, 1.0]
# Par values (fit) (array([-0.76451124, -0.6875965 , -1.38800041]), array([[ 1.09635222e-03, -9.36325335e-05,  2.26741925e-03],
#        [-9.36325335e-05,  2.99693485e-05, -2.48504095e-04],
#        [ 2.26741925e-03, -2.48504095e-04,  4.84960332e-03]]))
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# Setting deriv fit params {'_a1_': -0.7645112358059519, '_a0_': -0.687596501181607, '_a2_': -1.3880004093330303}
# Fit from fit 0.007603844783144493 3.8364696855475167e-07
# Fit from par 0.0076038447832598045 3.8323519016558727e-07
# Fit from fit 0.011776749849351432 7.77752129782483e-08
# Fit from par 0.011776749845759734 2.6006279504886542e-08
# Fit from fit 0.0003808051589339729 1.22952800718501e-10
# Fit from par 0.00038080515893380775 -6.276997671639251e-10
# Fit from fit 0.02205599379396065 5.630499966269298e-08
# Fit from par 0.02205599378571414 3.0427134603550066e-08
# Fit from fit 0.00795942538670029 8.671083304157001e-08
# Fit from par 0.00795942538617373 9.150528049173268e-08
# Fit from fit 0.005673461566481457 1.6409387876281656e-08
# Fit from par 0.005673461565500351 -4.987833757130744e-11
# Fit from fit 0.0011126792625693583 -1.0473534955979247e-09
# Fit from par 0.0011126792625597358 2.4783583102427897e-09
# Fit from fit 0.0010393414677884523 6.595661933284092e-10
# Fit from par 0.0010393414677844339 -9.135031481255496e-10
# Fit from fit 0.007015192281438176 5.610778786024895e-09
# Fit from par 0.0070151922806058805 5.390596607979248e-09
# Fit from fit nan nan
# Fit from par 0.007248824903146677 1.4198618203259405e-05
# R.S.18 Nitrogen Neg. Control_18
# Get SSE, fit 2 error(x0) No active exception to reraise
# [0.135914, -0.6535390498321059, -0.5210212900334169, -1.7284126662675021]
# [0.135914, 0.030185571705732567, -0.6766590695281229, 1.0]
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# No offset fit successful
# results ([0.135914, -0.6535390498321059, -0.5210212900334169, -1.7284126662675021], [[0.135914, -0.6535390498321059, -0.5210212900334169, -1.7284126662675021], [0.135914, -0.6535390498321059, -0.5210212900334169, -1.7284126662675021]])
# curvefit (array([-0.65353905, -0.52102129, -1.72841267]), array([[inf, inf, inf],
#        [inf, inf, inf],
#        [inf, inf, inf]]))
# curvefit deriv (array([-0.65353905, -0.52102129, -1.72841267]), array([[ 7.75496016e-04, -1.24374546e-05,  2.28629585e-03],
#        [-1.24374546e-05,  2.78417078e-06, -4.80317172e-05],
#        [ 2.28629585e-03, -4.80317172e-05,  6.94351170e-03]]))
# Inf in cov array. Raising error
# R.S.18 Nitrogen Neg. Control_18
# Get SSE, fit 2 error(no x0) No active exception to reraise
# Par values [0.030185571705732567, -0.6766590695281229, 1.0]
# Par values (fit) (array([-0.65353905, -0.52102129, -1.72841267]), array([[ 7.75496016e-04, -1.24374546e-05,  2.28629585e-03],
#        [-1.24374546e-05,  2.78417078e-06, -4.80317172e-05],
#        [ 2.28629585e-03, -4.80317172e-05,  6.94351170e-03]]))
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# Setting deriv fit params {'_a1_': -0.6535390498321059, '_a0_': -0.5210212900334169, '_a2_': -1.7284126662675021}
# Fit from fit 0.0059642245839657 3.612405801711738e-07
# Fit from par 0.005964224584055069 3.486698278709621e-07
# Fit from fit 0.0037751903152141563 2.5134283127004053e-09
# Fit from par 0.003775190315181716 -1.871527183228139e-09
# Fit from fit 0.011889904293738233 2.4065641124337844e-07
# Fit from par 0.011889904278151729 1.7230032475779034e-07
# Fit from fit 0.003422778448818211 3.896205025277766e-10
# Fit from par 0.0034227784488182035 -4.276655418689046e-10
# Fit from fit 0.013458798806139273 -1.2423138462391847e-08
# Fit from par 0.013458798804617466 -1.8711235977297846e-08
# Fit from fit nan nan
# Fit from par 0.053540476196721754 3.1742591365679917e-06
# R.S.19 D-Glucose_19
# Get SSE, fit 2 error(x0) No active exception to reraise
# [0.13046, -0.35700768372002484, -0.8887022520652988, -0.47786249872077063]
# [0.13046, 0.16879297337313431, -1.1059956010075722, 1.0]
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# No offset fit successful
# results ([0.13046, -0.35700768372002484, -0.8887022520652988, -0.47786249872077063], [[0.13046, -0.35700768372002484, -0.8887022520652988, -0.47786249872077063], [0.13046, -0.35700768372002484, -0.8887022520652988, -0.47786249872077063]])
# curvefit (array([-0.35700768, -0.88870225, -0.4778625 ]), array([[inf, inf, inf],
#        [inf, inf, inf],
#        [inf, inf, inf]]))
# curvefit deriv (array([-0.35700768, -0.88870225, -0.4778625 ]), array([[ 0.00072473, -0.00012244,  0.00113654],
#        [-0.00012244,  0.00012303, -0.00025455],
#        [ 0.00113654, -0.00025455,  0.00185928]]))
# Inf in cov array. Raising error
# R.S.19 D-Glucose_19
# Get SSE, fit 2 error(no x0) No active exception to reraise
# Par values [0.16879297337313431, -1.1059956010075722, 1.0]
# Par values (fit) (array([-0.35700768, -0.88870225, -0.4778625 ]), array([[ 0.00072473, -0.00012244,  0.00113654],
#        [-0.00012244,  0.00012303, -0.00025455],
#        [ 0.00113654, -0.00025455,  0.00185928]]))
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# Setting deriv fit params {'_a1_': -0.35700768372002484, '_a0_': -0.8887022520652988, '_a2_': -0.47786249872077063}
# Fit from fit nan nan
# #Cannot_fit:((_a1_*(B+_a0_))+(((B+_a0_)**2)*_a2_)) # # # # #
# #Cannot_fit:((_a1_*(B+_a0_))+(((B+_a0_)**2)*_a2_)) # # # # #
# #Cannot_fit:((_a1_*(B+_a0_))+(((B+_a0_)**2)*_a2_)) # # # # #
# Fit from par 0.011209944381004826 8.628312006431216e-06
# R.S.19 Guanidine_19
# Get SSE, fit 2 error(x0) No active exception to reraise
# [0.138953, -0.2627389755935549, -0.5355320651441293, -0.682855396601758]
# [0.138953, 0.10579646960307136, -0.8093420820238172, 1.0]
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# No offset fit successful
# results ([0.138953, -0.2627389755935549, -0.5355320651441293, -0.682855396601758], [[0.138953, -0.2627389755935549, -0.5355320651441293, -0.682855396601758], [0.138953, -0.2627389755935549, -0.5355320651441293, -0.682855396601758]])
# curvefit (array([-0.26273898, -0.53553207, -0.6828554 ]), array([[inf, inf, inf],
#        [inf, inf, inf],
#        [inf, inf, inf]]))
# curvefit deriv (array([-0.26273898, -0.53553207, -0.6828554 ]), array([[ 0.00061124, -0.00022345,  0.0021375 ],
#        [-0.00022345,  0.00017458, -0.00093851],
#        [ 0.0021375 , -0.00093851,  0.00781829]]))
# Inf in cov array. Raising error
# R.S.19 Guanidine_19
# Get SSE, fit 2 error(no x0) No active exception to reraise
# Par values [0.10579646960307136, -0.8093420820238172, 1.0]
# Par values (fit) (array([-0.26273898, -0.53553207, -0.6828554 ]), array([[ 0.00061124, -0.00022345,  0.0021375 ],
#        [-0.00022345,  0.00017458, -0.00093851],
#        [ 0.0021375 , -0.00093851,  0.00781829]]))
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# Setting deriv fit params {'_a1_': -0.2627389755935549, '_a0_': -0.5355320651441293, '_a2_': -0.682855396601758}
# Fit from fit nan nan
# Fit from par 0.4402191159573743 6.833225650093588e-06
# R.S.19 Cytidine_19
# Get SSE, fit 2 error(x0) No active exception to reraise
# [0.020659177345183303, -0.35532928328569324, -1.0611202820759815, -0.3924407686544002]
# [0.138135, -5.494088547406335, -1.5677754203557053, -0.09490230287925601]
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# No offset fit successful
# results ([0.138135, -0.35532928328569324, -1.0611202820759815, -0.3924407686544002], [[0.138135, -0.35532928328569324, -1.0611202820759815, -0.3924407686544002], [0.138135, -0.35532928328569324, -1.0611202820759815, -0.3924407686544002]])
# curvefit (array([-0.35532928, -1.06112028, -0.39244077]), array([[inf, inf, inf],
#        [inf, inf, inf],
#        [inf, inf, inf]]))
# curvefit deriv (array([-0.35532928, -1.06112028, -0.39244077]), array([[ 0.00076318, -0.00018257,  0.0009943 ],
#        [-0.00018257,  0.00021458, -0.00030881],
#        [ 0.0009943 , -0.00030881,  0.00135014]]))
# Inf in cov array. Raising error
# R.S.19 Cytidine_19
# Get SSE, fit 2 error(no x0) No active exception to reraise
# Par values [-5.494088547406335, -1.5677754203557053, -0.09490230287925601]
# Par values (fit) (array([-0.35532928, -1.06112028, -0.39244077]), array([[ 0.00076318, -0.00018257,  0.0009943 ],
#        [-0.00018257,  0.00021458, -0.00030881],
#        [ 0.0009943 , -0.00030881,  0.00135014]]))
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# Setting deriv fit params {'_a1_': -0.35532928328569324, '_a0_': -1.0611202820759815, '_a2_': -0.3924407686544002}
# Fit from fit 0.02791649017389368 4.78292748462561e-08
# Fit from par 0.02791649014146307 -4.419994875659583e-08
# Fit from fit nan nan
# Fit from par 0.03281915641091648 5.540552612759431e-06
# R.S.19 Alpha-D-Glucose_19
# Get SSE, fit 2 error(x0) No active exception to reraise
# [0.129447, -0.3465758588091698, -0.9319906118559969, -0.44111025424572886]
# [0.129447, 0.18362562632295049, -1.1426757441622553, 1.0]
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# No offset fit successful
# results ([0.129447, -0.3465758588091698, -0.9319906118559969, -0.44111025424572886], [[0.129447, -0.3465758588091698, -0.9319906118559969, -0.44111025424572886], [0.129447, -0.3465758588091698, -0.9319906118559969, -0.44111025424572886]])
# curvefit (array([-0.34657586, -0.93199061, -0.44111025]), array([[inf, inf, inf],
#        [inf, inf, inf],
#        [inf, inf, inf]]))
# curvefit deriv (array([-0.34657586, -0.93199061, -0.44111025]), array([[ 4.37204540e-04, -9.28412653e-05,  6.60655956e-04],
#        [-9.28412653e-05,  9.60626988e-05, -1.81189277e-04],
#        [ 6.60655956e-04, -1.81189277e-04,  1.04064798e-03]]))
# Inf in cov array. Raising error
# R.S.19 Alpha-D-Glucose_19
# Get SSE, fit 2 error(no x0) No active exception to reraise
# Par values [0.18362562632295049, -1.1426757441622553, 1.0]
# Par values (fit) (array([-0.34657586, -0.93199061, -0.44111025]), array([[ 4.37204540e-04, -9.28412653e-05,  6.60655956e-04],
#        [-9.28412653e-05,  9.60626988e-05, -1.81189277e-04],
#        [ 6.60655956e-04, -1.81189277e-04,  1.04064798e-03]]))
# Traceback (most recent call last):
#   File "/export/home/shared/Projects/IntegralBMS/Integral_BMS_Governing_Equations/Bacteria/rguimera-machine-scientist-constrained/mcmc_ode.py", line 835, in get_sse
#     raise
# RuntimeError: No active exception to reraise
#
# Setting deriv fit params {'_a1_': -0.3465758588091698, '_a0_': -0.9319906118559969, '_a2_': -0.44111025424572886}
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
# #Cannot_fit:((_a1_*(B+_a0_))+(((B+_a0_)**2)*_a2_)) # # # # #
# #Cannot_fit:((_a1_*(B+_a0_))+(((B+_a0_)**2)*_a2_)) # # # # #
# #Cannot_fit:((_a1_*(B+_a0_))+(((B+_a0_)**2)*_a2_)) # # # # #
# oo

# %%
def loss_ode(param):
    model=[]
    for value in x[col].B.to_numpy():
        model.append(value*(param[0]+param[2])+param[1]*(value+param[2])**2.)
    return np.sum(np.square(np.subtract(model,x[col].dx.to_numpy())))
def ode0(y,t,a,b,c):
    return (y+c)*a+b*(y+c)**2.
def fit_initial_value(x0):
    h=x[col].t[1]-x[col].t[0]
    #print('initial BMS fit',col)
    int0 = RK_BMS(bms_fulldata_new,x0[0],h,len(y[col]),col)
    return np.sum(np.square(np.subtract(int0,x[col].B.to_numpy())))

# %%
for col in list(x.keys()):
    h=x[col].t[1]-x[col].t[0]
    print('Initial BMS fit')
    int0 = RK_BMS(bms_fulldata_new,bms_fulldata_new.x0[str(bms_fulldata_new)][col],h,len(y[col]),col)
    plt.plot(x[col].t.to_numpy(),x[col].B.to_numpy())
    plt.plot(x[col].t.to_numpy(),int0)
    plt.show()
    if np.isinf(bms_fulldata_new.sse[col]):# or (bms_fulldata_new.par_values[col]['_a1_']<0. and bms_fulldata_new.par_values[col]['_a2_']>0.):
        """
        fit = scipy.optimize.minimize(loss_ode,[1.,1.,1.],bounds=((0.,10.),(-10.,0.),(None,None))).x
        print(fit)
        """
        
        #if bms_fulldata_new.par_values[col]['_a1_']<0. and bms_fulldata_new.par_values[col]['_a2_']>0.:
        print('alternative derivative fit')
        plt.plot(x[col].B.to_numpy(),x[col].dx.to_numpy(),label='ground truth')
        plt.plot(x[col].B.to_numpy(),ode0(x[col].B.to_numpy(),x[col].t.to_numpy(),
                                          bms_fulldata_new.par_values[col]['_a1_'],
                                            bms_fulldata_new.par_values[col]['_a2_'],
                                            bms_fulldata_new.par_values[col]['_a0_']),
                                          label='model')
        
        #plt.plot(x[col].B.to_numpy(),ode0(x[col].B.to_numpy(),x[col].t.to_numpy(),*fit),
        #                                  label='new fit model')
        plt.show()
        
        """    
        bms_fulldata_new.par_values[col]['_a1_'] = deepcopy(fit[0])
        bms_fulldata_new.par_values[col]['_a2_'] = deepcopy(fit[1])
        bms_fulldata_new.par_values[col]['_a0_'] = deepcopy(fit[2])
        bms_fulldata_new.x0[str(bms_fulldata_new)][col]=deepcopy(x[col].B.to_numpy()[0])
        
        bms_fulldata_new.get_bic(reset=True,fit=False,verbose=True)
        """
        if np.isinf(bms_fulldata_new.sse[col]):
            success=False
            init_points=np.linspace(x[col].B.to_numpy()[0],1.,1000)
            for i in init_points:
                bms_fulldata_new.x0[str(bms_fulldata_new)][col]=deepcopy(i)
                bms_fulldata_new.get_bic(reset=True,fit=False,verbose=True)
                print(i,bms_fulldata_new.sse[col])
                h=x[col].t[1]-x[col].t[0]
                int0 = RK_BMS(bms_fulldata_new,i,h,len(y[col]),col)
                if not np.isinf(bms_fulldata_new.sse[col]) and not np.isnan(sum(int0)) and not np.isinf(sum(int0)):
                    print('break!',bms_fulldata_new.sse[col],sum(int0))
                    success=True
                    break
            if success==None:
                print('sse not successful',bms_fulldata_new.sse[col])
                plt.plot(x[col].B.to_numpy(),x[col].dx.to_numpy(),label='ground truth')
                plt.plot(x[col].B.to_numpy(),ode0(x[col].B.to_numpy(),x[col].t.to_numpy(),*fit),label='model')
                plt.show()
        def func(x):
            return ode0(x,1.,bms_fulldata_new.par_values[col]['_a1_'],
                                            bms_fulldata_new.par_values[col]['_a2_'],
                                            bms_fulldata_new.par_values[col]['_a0_'])
        
        deriv_root=scipy.optimize.root_scalar(func, bracket=[0.0, max(x[col].B.to_numpy())*0.5]).root
        print((deriv_root+1e-3,0.5))
        new_x0 = scipy.optimize.minimize(fit_initial_value,bms_fulldata_new.x0[str(bms_fulldata_new)][col],bounds=[(deriv_root+1e-4,0.5)]).x
        print('optimized x0',new_x0)
        bms_fulldata_new.x0[str(bms_fulldata_new)][col]=deepcopy(new_x0[0])
    h=x[col].t[1]-x[col].t[0]
    print('final fit')
    int0 = RK_BMS(bms_fulldata_new,bms_fulldata_new.x0[str(bms_fulldata_new)][col],h,len(y[col]),col)
    plt.plot(x[col].t.to_numpy(),x[col].B.to_numpy())
    plt.plot(x[col].t.to_numpy(),int0)
    plt.show()
# Out:
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# alternative derivative fit
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0
inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.15625228228228227 2.1263011995843266
# break! 2.1263011995843266 25.82222376132381
# (0.15668610788443316, 0.5)
# optimized x0 [0.15859251]
# final fit
# Initial BMS fit
# final fit
# Initial BMS fit
# alternative derivative fit
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.129447 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13031842442442443 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13118984884884885 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13206127327327327 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.1329326976976977 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13380412212212212 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13467554654654657 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.135546970970971 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.1364183953953954 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13728981981981983 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13816124424424425 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.13903266866866867 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.1399040930930931 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.14077551751751752 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.14164694194194194 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.14251836636636636 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.14338979079079078 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.14426121521521523 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.14513263963963965 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# > Cannot calculate SSE for ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_)): inf
#
# 0.14600406406406408 inf
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# 0.1468754884884885 1.7764460928973507
# break! 1.7764460928973507 22.99071748987047
# (0.14730074073342897, 0.5)
# optimized x0 [0.14954452]
# final fit

# %%
bms_fulldata_new.fit_par={}
bms_fulldata_new.get_bic(reset=True,fit=False,verbose=True)
bms_fulldata_new.get_energy(reset=True)

print(bms_fulldata_new)
print(bms_fulldata_new.E)
print(bms_fulldata_new.sse)



f_name=f'{folder_name}/logistic_test_fit_t.pkl'
file = open(f_name,'wb')
pickle.dump(bms_fulldata_new,file)
file.close()
# Out:
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# ((_a1_ * (B + _a0_)) + (((B + _a0_) ** 2) * _a2_))
# -22416.1678545804
# {'H3': 0.016315911433953594, 'D6': 0.02520589963649872, 'C7': 0.05812003254697777, 'F3': 0.04374632148800191, 'B11': 0.009268766000162111, 'B12': 0.0024364386446481087, 'E12': 0.0026280115068637866, 'A3': 0.011276487503708854, 'G9': 0.002926731333784611, 'C11': 0.04625814515978148, 'D5': 0.012796275064734039, 'C5': 0.028738373918916864, 'D8': 0.0011394435138120966, 'A6': 0.0037552976910300196, 'B4': 0.015128035825352848, 'R.S.6 4 Hydroxy-Phenylacetate, 0.3%_6': 0.0017026287394551034, 'R.S.6 D-Trehalose, 0.3%_6': 0.009127340013702393, 'R.S.6 D-Arabitol, 0.3%_6': 0.005663462651096054, 'R.S.6 Alpha-D-Lactose, 0.3%_6': 0.005536990551123703, 'R.S.6 Malate, 0.3%_6': 0.0030833196449980226, 'R.S.6 D-Cellubiose, 0.3%_6': 0.01294212148813572, 'R.S.6 Allantoin, 0.2%_6': 0.01138516749848069, 'R.S.6 D-Raffinose, 0.3%_6': 0.02516538938339923, 'R.S.6 N-Acetyl-D-Glucosamine, 0.2%_6': 0.02577200846760708, 'R.S.6 D-Fructose, 0.3%_6': 0.004635860187539888, 'R.S.6 D-Xylose, 0.3%_6': 0.009220288356944648, 'R.S.6 Citrate, 0.3%_6': 0.0108078179481086, 'R.S.6 Adonitol, 0.3%_6': 0.009042265667332586, 'R.S.6 D-Glutamate, 0.2%_6': 0.01965795609421665, 'R.S.6 L-Arginine, 0.2%_6': 0.005812138664645634, 'R.S.6 Lactate, 0.3%_6': 0.0036491747861979945, 'R.S.6 L-Alanine, 0.3%_6': 0.0031188217836842012, 'R.S.6 Sucrose, 0.3%_6': 0.0105612753155084, 'R.S.6 D-Glucose, 0.3%_6': 0.028970200171186254, 'R.S.6 Adenosine, 0.2%.1_6': 0.007084184358880384, 'D Glucose 6 PO4_10': 0.008029458011560665, 'Adenosine_10': 0.014575755415291379, 